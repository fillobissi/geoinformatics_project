# %% [markdown]
# # Connection to VHR-REA CCLM downscaling ERA5 (0.02 Deg)

# %% [markdown]
# ### 1 - DATA CONNECTION

# %% [markdown]
# ##### Data source website (https://dds.cmcc.it/#/dataset/era5-downscaled-over-italy)
