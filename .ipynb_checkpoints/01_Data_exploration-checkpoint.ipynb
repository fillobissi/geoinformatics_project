# %% [markdown]
# ## 01 - DATA EXPLORATION

# %% [markdown]
# #### 01.1 - Libraries import

# %%
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import folium
from folium.plugins import HeatMap
import geopandas as gpd
from shapely.geometry import Polygon
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

# %% [markdown]
# #### 01.2 - Data exploration

# %%
# Apri il file NetCDF
dataset = xr.open_dataset(r"C:\Users\andre\OneDrive - Politecnico di Milano\Geoinformatics_project\data\data_downloads\initial_temps\air_temperature_era5-downscaled-over-italy_hourly_433833.nc")

# Mostro le informazioni di base del dataset
print(dataset)
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 4, rlat: 6, rlon: 10, bnds: 2)
# Coordinates:
#     height_2m                       float32 ...
#   * rlon                            (rlon) float64 -2.093 -2.073 ... -1.913
#   * rlat                            (rlat) float64 2.432 2.452 ... 2.512 2.532
#     lon                             (rlat, rlon) float32 ...
#     lat                             (rlat, rlon) float32 ...
#   * time                            (time) datetime64[ns] 2023-08-15T12:00:00...
# Dimensions without coordinates: bnds
# Data variables:
#     T_2M                            (time, rlat, rlon) float32 ...
#     crs_rotated_latitude_longitude  int64 ...
#     time_bnds                       (time, bnds) datetime64[ns] ...
# Attributes: (12/14)
#     CDI:             Climate Data Interface version 1.9.8 (https://mpimet.mpg...
#     Conventions:     CF-1.4
#     history:         Generated by CMCC DDS version 0.9.0 2024-10-24 15:41:50....
# ...

# %%
# Elenco le variabili del dataset
print(dataset.variables)
# Out:
# Frozen({'T_2M': <xarray.Variable (time: 4, rlat: 6, rlon: 10)>
# [240 values with dtype=float32]
# Attributes:
#     standard_name:  air_temperature
#     long_name:      2m temperature
#     units:          K
#     grid_mapping:   crs_rotated_latitude_longitude, 'crs_rotated_latitude_longitude': <xarray.Variable ()>
# [1 values with dtype=int64]
# Attributes:
#     grid_north_pole_latitude:   47.0
#     grid_north_pole_longitude:  -168.0
#     grid_mapping_name:          rotated_latitude_longitude, 'height_2m': <xarray.Variable ()>
# [1 values with dtype=float32]
# Attributes:
#     standard_name:  height
#     long_name:      height above the surface
#     positive:       up
#     axis:           Z
#     units:          m, 'rlon': <xarray.IndexVariable 'rlon' (rlon: 10)>
# array([-2.093245, -2.073245, -2.053245, -2.033245, -2.013245, -1.993245,
#        -1.973245, -1.953245, -1.933245, -1.913245])
# Attributes:
#     standard_name:  grid_longitude
# ...

# %%
# Visualizzo informazioni dettagliate sulla variabile di temperatura
print(dataset['T_2M'])
# Out:
# <xarray.DataArray 'T_2M' (time: 4, rlat: 6, rlon: 10)>
# [240 values with dtype=float32]
# Coordinates:
#     height_2m  float32 ...
#   * rlon       (rlon) float64 -2.093 -2.073 -2.053 ... -1.953 -1.933 -1.913
#   * rlat       (rlat) float64 2.432 2.452 2.472 2.492 2.512 2.532
#     lon        (rlat, rlon) float32 ...
#     lat        (rlat, rlon) float32 ...
#   * time       (time) datetime64[ns] 2023-08-15T12:00:00 ... 2023-08-15T15:00:00
# Attributes:
#     standard_name:  air_temperature
#     long_name:      2m temperature
#     units:          K
#     grid_mapping:   crs_rotated_latitude_longitude

# %%
# Converte il dataset in un DataFrame di pandas
df = dataset.to_dataframe()
df

# Salva il DataFrame in un file CSV
df.to_csv(r"C:\Users\andre\OneDrive - Politecnico di Milano\Geoinformatics_project\elab\temp_outs\dati_esportati.csv")

# %% [markdown]
# #### 01.3 - First heat map attempt visualization

# %%
# Seleziona la variabile di temperatura (assumendo che si chiami 'air_temperature')
temperature = dataset['T_2M']

# Calcola la temperatura media sull'intervallo di tempo (se applicabile)
temperature_mean = temperature.mean(dim='time')

# Plotta la temperatura media
temperature_mean.plot()
plt.title("Temperatura media")
plt.show()

# %%
# Converte il dataset in un DataFrame di Pandas
df = temperature_mean.to_dataframe().reset_index()

# Crea una mappa con Folium centrata sull'Italia
mappa = folium.Map(location=[45.45, 9.15], zoom_start=11.4)

# Aggiungi i dati di temperatura come punti di calore (heatmap)
heat_data = [[row['lat'], row['lon'], row['T_2M']] for index, row in df.iterrows()]
HeatMap(heat_data, radius=9, blur=15, max_zoom=13).add_to(mappa)

# Mostra la mappa
mappa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 01.4 - Rough inital data spatialization

# %%
# Crea una mappa centrata su Milano
mappa = folium.Map(location=[45.45, 9.15], zoom_start=11.4)

# Crea un GeoDataFrame che rappresenta le celle dei dati ERA5
celle = []

for _, row in df.iterrows():
    # Definisci un rettangolo per ogni cella di temperatura (approssimando le coordinate della cella)
    lat, lon = row['lat'], row['lon']
    delta = 0.02  # Estensione della cella (modificabile in base alla risoluzione dei dati)
    polygon = Polygon([
        (lon - delta, lat - delta),
        (lon - delta, lat + delta),
        (lon + delta, lat + delta),
        (lon + delta, lat - delta)
    ])
    celle.append({'geometry': polygon, 'temperature': row['T_2M']})

# Crea un GeoDataFrame con tutte le celle
gdf = gpd.GeoDataFrame(celle)

# Normalizza i valori di temperatura per la colorazione
norm = plt.Normalize(vmin=gdf['temperature'].min(), vmax=gdf['temperature'].max())
cmap = plt.get_cmap('viridis')

# Aggiungi le celle alla mappa come poligoni
for _, row in gdf.iterrows():
    color = mcolors.to_hex(cmap(norm(row['temperature'])))
    folium.Polygon(
        locations=[(coord[1], coord[0]) for coord in row['geometry'].exterior.coords],
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.5,
        weight=0
    ).add_to(mappa)

# Mostra la mappa
mappa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
