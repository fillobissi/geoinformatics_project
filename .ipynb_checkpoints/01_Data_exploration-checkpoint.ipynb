# %% [markdown]
# ## 01 - DATA EXPLORATION

# %% [markdown]
# #### 01.1 - Libraries import

# %%
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import folium
from folium.plugins import HeatMap
import geopandas as gpd
from shapely.geometry import Polygon
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### 01.2 - Data exploration

# %%
# Apri il file NetCDF
dataset1 = xr.open_dataset(r"C:\Users\andre\OneDrive - Politecnico di Milano\Geoinformatics_project\data\data_downloads\era5-downscaled-over-italy_hourly_437292.nc")
dataset2 = xr.open_dataset(r"C:\Users\andre\OneDrive - Politecnico di Milano\Geoinformatics_project\data\data_downloads\air_temperature_era5-downscaled-over-italy_hourly_442373.nc")
# Mostro le informazioni di base del dataset
print("Dataset 1: ", "\n", dataset1)
print("Dataset 2: ", "\n", dataset2)

# Confronto se i 2 dataset sono uguali
if dataset1.equals(dataset2):
    print("I dataset sono uguali.")
else:
    print("I dataset sono diversi.")
# Out:
# Dataset 1:
#  <xarray.Dataset>
# Dimensions:                         (time: 23736, rlat: 90, rlon: 74, bnds: 2)
# Coordinates:
#   * rlon                            (rlon) float64 -2.473 -2.453 ... -1.013
#     height_2m                       float32 ...
#     lon                             (rlat, rlon) float32 ...
#   * rlat                            (rlat) float64 1.812 1.832 ... 3.572 3.592
#     lat                             (rlat, rlon) float32 ...
#   * time                            (time) datetime64[ns] 1981-06-01T11:00:00...
# Dimensions without coordinates: bnds
# Data variables:
#     TMAX_2M                         (time, rlat, rlon) float32 ...
#     crs_rotated_latitude_longitude  int64 ...
#     time_bnds                       (time, bnds) datetime64[ns] ...
#     TD_2M                           (time, rlat, rlon) float32 ...
# Attributes: (12/14)
#     CDI:             Climate Data Interface version 1.9.8 (https://mpimet.mpg...
#     Conventions:     CF-1.4
# ...

# %%
# Elenco le variabili del dataset
print(dataset2.variables)
# Out:
# Frozen({'T_2M': <xarray.Variable (time: 23736, rlat: 90, rlon: 74)>
# array([[[301.24036, 301.47424, ..., 302.69522, 302.5517 ],
#         [301.42368, 301.58728, ..., 302.56097, 302.57593],
#         ...,
#         [282.48508, 276.79822, ..., 288.2214 , 288.9719 ],
#         [278.94193, 276.6708 , ..., 286.26257, 288.64316]],
#
#        [[302.45578, 302.84598, ..., 303.69272, 303.54907],
#         [302.6126 , 302.91983, ..., 303.5536 , 303.59668],
#         ...,
#         [282.6607 , 276.8323 , ..., 287.61353, 289.1195 ],
#         [278.87018, 276.7121 , ..., 288.0611 , 288.82498]],
#
#        ...,
#
#        [[299.00232, 299.283  , ..., 304.33206, 304.03348],
#         [299.0214 , 299.36838, ..., 303.6947 , 304.21234],
#         ...,
#         [280.45737, 276.67197, ..., 282.5135 , 284.42883],
#         [280.74316, 276.41666, ..., 282.4396 , 284.45184]],
#
#        [[297.81128, 298.03415, ..., 302.9988 , 303.2291 ],
#         [297.81543, 298.16208, ..., 302.92062, 303.1412 ],
# ...

# %%
print(dataset2.data_vars)
# Out:
# Data variables:
#     T_2M                            (time, rlat, rlon) float32 301.2 ... 284.0
#     crs_rotated_latitude_longitude  int64 ...
#     time_bnds                       (time, bnds) datetime64[ns] ...

# %% [markdown]
# #### Recap dei datasets and their contents
# ##### Dataset 1
# TMAX_2M :   2m maximum temperature
#
# TD_2M   :   2m dew point temperature
# ##### Dataset 2
# T_2M    :   2m temperature

# %%
# Visualizzo informazioni dettagliate sulla variabile di temperatura
print(dataset1['TD_2M'])
# Out:
# <xarray.DataArray 'TD_2M' (time: 23736, rlat: 90, rlon: 74)>
# [158081760 values with dtype=float32]
# Coordinates:
#   * rlon       (rlon) float64 -2.473 -2.453 -2.433 ... -1.053 -1.033 -1.013
#     height_2m  float32 ...
#     lon        (rlat, rlon) float32 ...
#   * rlat       (rlat) float64 1.812 1.832 1.852 1.872 ... 3.552 3.572 3.592
#     lat        (rlat, rlon) float32 ...
#   * time       (time) datetime64[ns] 1981-06-01T11:00:00 ... 2023-08-31T16:00:00
# Attributes:
#     standard_name:  dew_point_temperature
#     long_name:      2m dew point temperature
#     units:          K
#     grid_mapping:   crs_rotated_latitude_longitude

# %% [markdown]
# #### Plot spaziale dei dati

# %%
# Funzione plot() integrata in xarray per visualizzare facilmente i dati
dataset2['T_2M'].isel(time=0).plot()

# %% [markdown]
# #### Histogrammi di visualizzazione medie

# %%
# Set up for the mean temperature istogram
# Calcola la media spaziale per ogni timestamp lungo le dimensioni 'rlat' e 'rlon'
temperature_mean_over_space = dataset2['T_2M'].mean(dim=['rlat', 'rlon'])

# Converti la temperatura in gradi Celsius
temperature_mean_over_space_celsius = temperature_mean_over_space - 273.15

# Crea un grafico per visualizzare la media di temperatura nel tempo (con line plot e riducendo il numero di punti per migliorare la leggibilità)
plt.figure(figsize=(12, 6))
temperature_mean_over_space_celsius.plot.line(color='b', alpha=0.7)
plt.xlabel("Anno")
plt.ylabel("Temperatura Media (°C)")
plt.title("Temperatura Media per ogni timestamp")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Calcola la media spaziale per ogni timestamp lungo le dimensioni 'rlat' e 'rlon'
temperature_mean_over_space = (dataset2['T_2M'].mean(dim=['rlat', 'rlon'])) - 273.15

# Converte il risultato in un DataFrame per facilitarne la manipolazione
temperature_mean_df = temperature_mean_over_space.to_dataframe().reset_index()

# Crea una colonna 'year' che contiene solo l'anno di ogni timestamp
temperature_mean_df['year'] = temperature_mean_df['time'].dt.year

# Calcola la media di temperatura per ciascun anno
annual_temperature_mean = temperature_mean_df.groupby('year')['T_2M'].mean()

# Crea un grafico a linea per la media annuale della temperatura
plt.figure(figsize=(12, 6))
plt.plot(annual_temperature_mean.index, annual_temperature_mean.values, linestyle='-', color='r')
plt.xlabel("Anno")
plt.ylabel("Temperatura Media (°C)")
plt.title("Media Annuale della Temperatura Media tra Latitudine e Longitudine")
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)  # Ruota le etichette degli anni sull'asse x per renderle più leggibili
plt.show()

# %%
# Calcola la media spaziale per ogni timestamp lungo le dimensioni 'rlat' e 'rlon'
temperature_mean_over_space = (dataset1['TD_2M'].mean(dim=['rlat', 'rlon'])) - 273.15

# Converte il risultato in un DataFrame per facilitarne la manipolazione
temperature_mean_df = temperature_mean_over_space.to_dataframe().reset_index()

# Crea una colonna 'year' che contiene solo l'anno di ogni timestamp
temperature_mean_df['year'] = temperature_mean_df['time'].dt.year

# Calcola la media di temperatura per ciascun anno
annual_temperature_mean = temperature_mean_df.groupby('year')['TD_2M'].mean()

# Crea un grafico a linea per la media annuale della temperatura
plt.figure(figsize=(12, 6))
plt.plot(annual_temperature_mean.index, annual_temperature_mean.values, linestyle='-', color='b')
plt.xlabel("Anno")
plt.ylabel("Temperatura Media (°C)")
plt.title("Media Annuale della dew point temperature tra Latitudine e Longitudine")
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)  # Ruota le etichette degli anni sull'asse x per renderle più leggibili
plt.show()

# %%
# Seleziona la variabile di temperatura (assumendo che si chiami 'air_temperature')
temperature = dataset['T_2M']

# Calcola la temperatura media sull'intervallo di tempo (se applicabile)
temperature_mean = temperature.mean(dim='time')

# Plotta la temperatura media
temperature_mean.plot()
plt.title("Temperatura media")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Filtra entrambi i dataset per un anno specifico, ad esempio 2002
year = 1983
temperature_ds = dataset2['T_2M'].sel(time=dataset2['T_2M'].time.dt.year == year)  # In Kelvin
dew_point_ds = dataset1['TD_2M'].sel(time=dataset1['TD_2M'].time.dt.year == year)  # In Kelvin

# Verifica che entrambi abbiano gli stessi timestamp
if not temperature_ds.time.equals(dew_point_ds.time):
    raise ValueError("I timestamp dei due dataset non coincidono per l'anno selezionato!")

# Sostituisci i valori di dew point non credibili con la media dei valori limitrofi tramite interpolazione lineare
dew_point_ds_filtered = dew_point_ds.where(dew_point_ds > 243.15)  # Dew point non credibili < -30°C
dew_point_ds_interpolated = dew_point_ds_filtered.interpolate_na(dim='time', method='linear')

# Calcola l'Humidex per ciascun timestamp e media spazialmente (in Kelvin)
humidex = temperature_ds + 3.394444 * np.exp(19.833625 - (5417.7530 / dew_point_ds_interpolated)) - 5.555556

# Calcola il valore massimo dell'Humidex per ciascun giorno
humidex_daily_max = humidex.resample(time='1D').max(dim=['time', 'rlat', 'rlon'])

# Converte l'Humidex in gradi Celsius per visualizzare i risultati
humidex_daily_max_celsius = humidex_daily_max - 273.15

# Converte il risultato in un DataFrame per una più semplice visualizzazione
humidex_daily_max_df = humidex_daily_max_celsius.to_dataframe(name='Humidex').reset_index()

# Trova il giorno con il valore massimo di Humidex e la temperatura di quel giorno
max_humidex_value = humidex_daily_max_celsius.max()
max_humidex_day = humidex_daily_max_celsius.time.where(humidex_daily_max_celsius == max_humidex_value, drop=True).values[0]

# Recupera la temperatura massima di quel giorno
temperature_max_day = temperature_ds.sel(time=max_humidex_day, method='nearest').max(dim=['rlat', 'rlon']) - 273.15  # Converti in gradi Celsius

# Stampa i risultati
print("Valori massimi di Humidex (°C) per ciascun giorno dell'anno:")
print(humidex_daily_max_df)
print(f"\nIl valore massimo dell'Humidex per l'anno {year} è: {max_humidex_value.values:.2f} °C")
print(f"Il giorno corrispondente è: {np.datetime_as_string(max_humidex_day, unit='D')}")
print(f"La temperatura massima di quel giorno è: {temperature_max_day.values:.2f} °C")

# Crea un grafico a linee per visualizzare i valori massimi di Humidex giornalieri
plt.figure(figsize=(12, 6))
plt.plot(humidex_daily_max_df['time'], humidex_daily_max_df['Humidex'], linestyle='-', color='b', marker='o')
plt.xlabel("Data")
plt.ylabel("Humidex Giornaliero Massimo (°C)")
plt.title(f"Valore Massimo di Humidex Giornaliero per l'Anno {year}")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)  # Ruota le etichette degli anni sull'asse x per renderle più leggibili
plt.tight_layout()
plt.show()
# Out:
# Valori massimi di Humidex (°C) per ciascun giorno dell'anno:
#          time  height_2m    Humidex
# 0  1983-06-01        2.0  36.156189
# 1  1983-06-02        2.0  35.465759
# 2  1983-06-03        2.0  37.047180
# 3  1983-06-04        2.0  39.407318
# 4  1983-06-05        2.0  40.503784
# ..        ...        ...        ...
# 87 1983-08-27        2.0  38.996521
# 88 1983-08-28        2.0  39.133179
# 89 1983-08-29        2.0  35.800507
# 90 1983-08-30        2.0  36.287140
# 91 1983-08-31        2.0  36.948822
#
# [92 rows x 3 columns]
#
# Il valore massimo dell'Humidex per l'anno 1983 è: 47.00 °C
# Il giorno corrispondente è: 1983-07-26
# La temperatura massima di quel giorno è: 42.23 °C

# %% [markdown]
# #### 01.4 - Rough inital data spatialization

# %%
# Crea una mappa centrata su Milano
mappa = folium.Map(location=[45.45, 9.15], zoom_start=11.4)

# Crea un GeoDataFrame che rappresenta le celle dei dati ERA5
celle = []

for _, row in df.iterrows():
    # Definisci un rettangolo per ogni cella di temperatura (approssimando le coordinate della cella)
    lat, lon = row['lat'], row['lon']
    delta = 0.02  # Estensione della cella (modificabile in base alla risoluzione dei dati)
    polygon = Polygon([
        (lon - delta, lat - delta),
        (lon - delta, lat + delta),
        (lon + delta, lat + delta),
        (lon + delta, lat - delta)
    ])
    celle.append({'geometry': polygon, 'temperature': row['T_2M']})

# Crea un GeoDataFrame con tutte le celle
gdf = gpd.GeoDataFrame(celle)

# Normalizza i valori di temperatura per la colorazione
norm = plt.Normalize(vmin=gdf['temperature'].min(), vmax=gdf['temperature'].max())
cmap = plt.get_cmap('viridis')

# Aggiungi le celle alla mappa come poligoni
for _, row in gdf.iterrows():
    color = mcolors.to_hex(cmap(norm(row['temperature'])))
    folium.Polygon(
        locations=[(coord[1], coord[0]) for coord in row['geometry'].exterior.coords],
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.5,
        weight=0
    ).add_to(mappa)

# Mostra la mappa
mappa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
